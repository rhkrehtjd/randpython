# %%
import os
import sys
import urllib.request 
import datetime 
import time
import json
import pandas as pd
ServiceKey = "%2FAGmNcuIUpiDknm8ofZGh7ZnKg%2BRGByIUaB3f7uP5peV9FVZv1TeJhUx11N1MefdclPL287n%2BKHHjbVQbCIzBA%3D%3D"

def getRequestUrl(url):
    req = urllib.request.Request(url)
    try:
        response = urllib.request.urlopen(req)
        if response.getcode() == 200:
            print("[%s] Url Request Success" % datetime.datetime.now())
            return response.read().decode('utf-8')
    except Exception as e:
        print(e)
        print("[%s] Error for URL : %s" % (datetime.datetime.now(), url))
        return None

def getTourismStatsItem(yyyymm, nat_cd, ed_cd):
    service_url = "http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList"
    parameters = "?_type=json&serviceKey=" + ServiceKey #인증키
    parameters += "&YM=" + yyyymm
    parameters += "&NAT_CD=" + nat_cd
    parameters += "&ED_CD=" + ed_cd
    
    url = service_url + parameters
    
    responseDecode = getRequestUrl(url) #[CODE 1]
    
    if (responseDecode == None):
        return None
    else:
        return json.loads(responseDecode)

def getTourismStatsService(nat_cd, ed_cd, nStartYear, nEndYear):
    jsonResult = []
    result = []
    natName=''
    dataEND = "{0}{1:0>2}".format(str(nEndYear), str(12))
    isDataEnd = 0
    #ed=''
    for year in range(nStartYear, nEndYear+1):
        for month in range(1, 13):
            if(isDataEnd == 1):
                break
            yyyymm = "{0}{1:0>2}".format(str(year), str(month))
            jsonData = getTourismStatsItem(yyyymm, nat_cd, ed_cd) #[CODE 2]
            print(year, month, jsonData['response']['header']['resultMsg'])     #이부분을 추가해서 Crawl 결과가 잘 나오는지 체크
            if (jsonData['response']['header']['resultMsg'] == 'OK'):
                #데이터가 없는 마지막 항목인 경우 ----------------------------
                if jsonData['response']['body']['items'] == '':
                    isDataEnd = 1
                    dataEND = "{0}{1:0>2}".format(str(year), str(month-1))
                    print("데이터 없음.... \n제공되는 통계 데이터는 %s년 %s월까지입니다."%(str(year), str(month-1)))
                    break
                    #jsonData를 출력하여 확인............................................
                print(json.dumps(jsonData, indent = 4,sort_keys = True, ensure_ascii = False))
                natName = jsonData['response']['body']['items']['item']['natKorNm']
                natName = natName.replace(' ', '')
                num = jsonData['response']['body']['items']['item']['num']
                ed = jsonData['response']['body']['items']['item']['ed']
                print('[ %s_%s : %s ]' %(natName, yyyymm, num))
                print('------------------------------------------------------')
                jsonResult.append({'nat_name': natName, 'nat_cd': nat_cd,'yyyymm': yyyymm, 'visit_cnt': num})
                result.append([natName, nat_cd, yyyymm, num])

    
    return (jsonResult, result, natName, ed, dataEND)


def main():
    jsonResult = []
    result = []
    
    print("<< 국내 입국한 외국인의 통계 데이터를 수집합니다. >>")
    nat_cd = input('국가 코드를 입력하세요(중국: 112 / 일본: 130 / 미국: 275) :')
    nStartYear = int(input('데이터를 몇 년부터 수집할까요? : '))
    nEndYear = int(input('데이터를 몇 년까지 수집할까요? : '))
    ed_cd="E" #E:방한외래관광객,D:해외출국
    jsonResult, result, natName, ed, dataEND = getTourismStatsService(nat_cd, ed_cd, nStartYear, nEndYear) #[CODE 3]
    
    #파일저장 1 : json 파일
    with open('./%s_%s_%d_%s.json' % (natName, ed, nStartYear, dataEND),'w',encoding='utf8') as outfile:
        jsonFile = json.dumps(jsonResult, indent = 4, sort_keys = True,ensure_ascii = False)
        outfile.write(jsonFile)
    
    
    columns = ["입국자국가", "국가코드", "입국연월", "입국자 수"]
    result_df = pd.DataFrame(result, columns = columns)
    result_df.to_csv('./%s_%s_%d_%s.csv' % (natName, ed, nStartYear, dataEND),index = False, encoding = 'cp949')

# %%
main()
# Out:
# << 국내 입국한 외국인의 통계 데이터를 수집합니다. >>
# 국가 코드를 입력하세요(중국: 112 / 일본: 130 / 미국: 275) : 130
# 데이터를 몇 년부터 수집할까요? :  2019
# 데이터를 몇 년까지 수집할까요? :  2021
# [2023-04-06 12:25:36.282818] Url Request Success
# 2019 1 OK
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 206526,
#                     "rnum": 1,
#                     "ym": 201901
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_201901 : 206526 ]
# ------------------------------------------------------
# [2023-04-06 12:25:36.338497] Url Request Success
# 2019 2 OK
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 213200,
#                     "rnum": 1,
#                     "ym": 201902
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_201902 : 213200 ]
# ------------------------------------------------------
# [2023-04-06 12:25:36.410581] Url Request Success
# 2019 3 OK
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 375119,
#                     "rnum": 1,
#                     "ym": 201903
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_201903 : 375119 ]
# ------------------------------------------------------
# [2023-04-06 12:25:36.467359] Url Request Success
# 2019 4 OK
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 290092,
#                     "rnum": 1,
#                     "ym": 201904
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_201904 : 290092 ]
# ------------------------------------------------------
# [2023-04-06 12:25:36.640757] Url Request Success
# 2019 5 OK
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 286273,
#                     "rnum": 1,
#                     "ym": 201905
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_201905 : 286273 ]
# ------------------------------------------------------
# [2023-04-06 12:25:36.760718] Url Request Success
# 2019 6 OK
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 282476,
#                     "rnum": 1,
#                     "ym": 201906
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_201906 : 282476 ]
# ------------------------------------------------------
# [2023-04-06 12:25:36.817699] Url Request Success
# 2019 7 OK
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 274830,
#                     "rnum": 1,
#                     "ym": 201907
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_201907 : 274830 ]
# ------------------------------------------------------
# [2023-04-06 12:25:36.873039] Url Request Success
# 2019 8 OK
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 329652,
#                     "rnum": 1,
#                     "ym": 201908
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_201908 : 329652 ]
# ------------------------------------------------------
# [2023-04-06 12:25:36.955174] Url Request Success
# 2019 9 OK
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 251119,
#                     "rnum": 1,
#                     "ym": 201909
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_201909 : 251119 ]
# ------------------------------------------------------
# [2023-04-06 12:25:37.023681] Url Request Success
# 2019 10 OK
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 248541,
#                     "rnum": 1,
#                     "ym": 201910
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_201910 : 248541 ]
# ------------------------------------------------------
# [2023-04-06 12:25:37.080365] Url Request Success
# 2019 11 OK
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 258522,
#                     "rnum": 1,
#                     "ym": 201911
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_201911 : 258522 ]
# ------------------------------------------------------
# [2023-04-06 12:25:37.285137] Url Request Success
# 2019 12 OK
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 255356,
#                     "rnum": 1,
#                     "ym": 201912
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_201912 : 255356 ]
# ------------------------------------------------------
# [2023-04-06 12:25:37.339539] Url Request Success
# 2020 1 OK
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 203969,
#                     "rnum": 1,
#                     "ym": 202001
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_202001 : 203969 ]
# ------------------------------------------------------
# [2023-04-06 12:25:37.416073] Url Request Success
# 2020 2 OK
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 211199,
#                     "rnum": 1,
#                     "ym": 202002
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_202002 : 211199 ]
# ------------------------------------------------------
# [2023-04-06 12:25:37.472572] Url Request Success
# 2020 3 OK
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 8347,
#                     "rnum": 1,
#                     "ym": 202003
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_202003 : 8347 ]
# ------------------------------------------------------
# [2023-04-06 12:25:37.534575] Url Request Success
# 2020 4 OK
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 360,
#                     "rnum": 1,
#                     "ym": 202004
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_202004 : 360 ]
# ------------------------------------------------------
# [2023-04-06 12:25:37.678700] Url Request Success
# 2020 5 OK
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 413,
#                     "rnum": 1,
#                     "ym": 202005
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_202005 : 413 ]
# ------------------------------------------------------
# [2023-04-06 12:25:37.828226] Url Request Success
# 2020 6 OK
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 498,
#                     "rnum": 1,
#                     "ym": 202006
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_202006 : 498 ]
# ------------------------------------------------------
# [2023-04-06 12:25:37.884837] Url Request Success
# 2020 7 OK
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 755,
#                     "rnum": 1,
#                     "ym": 202007
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_202007 : 755 ]
# ------------------------------------------------------
# [2023-04-06 12:25:37.946368] Url Request Success
# 2020 8 OK
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 1275,
#                     "rnum": 1,
#                     "ym": 202008
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_202008 : 1275 ]
# ------------------------------------------------------
# [2023-04-06 12:25:38.002877] Url Request Success
# 2020 9 OK
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 794,
#                     "rnum": 1,
#                     "ym": 202009
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_202009 : 794 ]
# ------------------------------------------------------
# [2023-04-06 12:25:38.079219] Url Request Success
# 2020 10 OK
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 927,
#                     "rnum": 1,
#                     "ym": 202010
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_202010 : 927 ]
# ------------------------------------------------------
# [2023-04-06 12:25:38.150397] Url Request Success
# 2020 11 OK
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 1254,
#                     "rnum": 1,
#                     "ym": 202011
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_202011 : 1254 ]
# ------------------------------------------------------
# [2023-04-06 12:25:38.339284] Url Request Success
# 2020 12 OK
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 951,
#                     "rnum": 1,
#                     "ym": 202012
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_202012 : 951 ]
# ------------------------------------------------------
# [2023-04-06 12:25:38.390721] Url Request Success
# 2021 1 OK
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 1299,
#                     "rnum": 1,
#                     "ym": 202101
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_202101 : 1299 ]
# ------------------------------------------------------
# [2023-04-06 12:25:38.464042] Url Request Success
# 2021 2 OK
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 1719,
#                     "rnum": 1,
#                     "ym": 202102
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_202102 : 1719 ]
# ------------------------------------------------------
# [2023-04-06 12:25:38.544419] Url Request Success
# 2021 3 OK
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 949,
#                     "rnum": 1,
#                     "ym": 202103
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_202103 : 949 ]
# ------------------------------------------------------
# [2023-04-06 12:25:38.600578] Url Request Success
# 2021 4 OK
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 872,
#                     "rnum": 1,
#                     "ym": 202104
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_202104 : 872 ]
# ------------------------------------------------------
# [2023-04-06 12:25:38.841362] Url Request Success
# 2021 5 OK
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 1403,
#                     "rnum": 1,
#                     "ym": 202105
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_202105 : 1403 ]
# ------------------------------------------------------
# [2023-04-06 12:25:38.918330] Url Request Success
# 2021 6 OK
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 875,
#                     "rnum": 1,
#                     "ym": 202106
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_202106 : 875 ]
# ------------------------------------------------------
# [2023-04-06 12:25:38.975639] Url Request Success
# 2021 7 OK
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 881,
#                     "rnum": 1,
#                     "ym": 202107
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_202107 : 881 ]
# ------------------------------------------------------
# [2023-04-06 12:25:39.056243] Url Request Success
# 2021 8 OK
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 2258,
#                     "rnum": 1,
#                     "ym": 202108
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_202108 : 2258 ]
# ------------------------------------------------------
# [2023-04-06 12:25:39.110588] Url Request Success
# 2021 9 OK
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 1142,
#                     "rnum": 1,
#                     "ym": 202109
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_202109 : 1142 ]
# ------------------------------------------------------
# [2023-04-06 12:25:39.171537] Url Request Success
# 2021 10 OK
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 1237,
#                     "rnum": 1,
#                     "ym": 202110
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_202110 : 1237 ]
# ------------------------------------------------------
# [2023-04-06 12:25:39.386928] Url Request Success
# 2021 11 OK
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 1623,
#                     "rnum": 1,
#                     "ym": 202111
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_202111 : 1623 ]
# ------------------------------------------------------
# [2023-04-06 12:25:39.445146] Url Request Success
# 2021 12 OK
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 130,
#                     "natKorNm": "일  본",
#                     "num": 1007,
#                     "rnum": 1,
#                     "ym": 202112
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 일본_202112 : 1007 ]
# ------------------------------------------------------
